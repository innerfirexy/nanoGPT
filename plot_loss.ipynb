# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Read loss data
def read_loss_from_log(log_file):
    losses = []
    with open(log_file, 'r') as f:
        for line in f:
            if 'val loss' in line:
                losses.append(float(line.split('val loss')[1].strip()))
    return losses

shkspr_char_loss = read_loss_from_log('./out-shakespeare-char/log.txt')
print(shkspr_char_loss)

shkspr_char_loss_cepred = read_loss_from_log('./out-shakespeare-char-cepred/log_0.5.txt')
print(shkspr_char_loss_cepred)

shkspr_char_loss_cepred2 = read_loss_from_log('./out-shakespeare-char-cepred/log_0.9.txt')
print(shkspr_char_loss_cepred2)

shkspr_char_loss_cepred3 = read_loss_from_log('./out-shakespeare-char-cepred/log_0.1.txt')
print(shkspr_char_loss_cepred3)
# Out:
# [4.3422, 2.0707, 1.7501, 1.5894, 1.5176, 1.4979, 1.4823, 1.472, 1.4752, 1.4981, 1.5068, 1.5283, 1.5446, 1.5784, 1.5823, 1.6114, 1.6419, 1.6544, 1.6903, 1.7008, 1.7189]
# [4.3422, 2.0686, 1.7532, 1.5907, 1.5196, 1.4989, 1.4805, 1.4717, 1.4715, 1.4787, 1.4945, 1.5121, 1.5325, 1.5627, 1.5732, 1.5954, 1.6278, 1.6455, 1.6684, 1.6788, 1.7027]
# [4.3422, 2.0726, 1.7474, 1.5988, 1.5161, 1.4971, 1.4872, 1.478, 1.4771, 1.4867, 1.5011, 1.5215, 1.5369, 1.5671, 1.5805, 1.6027, 1.6323, 1.6455, 1.6778, 1.686, 1.7041]
# [4.3422, 2.0696, 1.7526, 1.59, 1.5131, 1.5047, 1.4922, 1.4847, 1.4736, 1.496, 1.508, 1.5192, 1.5375, 1.5693, 1.5792, 1.608, 1.6415, 1.6532, 1.6814, 1.6913, 1.7139]

# %%
# Plot loss curves

plt.plot(shkspr_char_loss[2:], label='Char')
plt.plot(shkspr_char_loss_cepred[2:], label='Char + CEPred 0.5')
plt.plot(shkspr_char_loss_cepred2[2:], label='Char + CEPred 0.9')
plt.plot(shkspr_char_loss_cepred3[2:], label='Char + CEPred 0.1')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
